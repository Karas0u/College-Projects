# %%
import openai

# Set up your API key
openai.api_key = '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'

# Define a function to interact with the ChatGPT API
def chat_with_gpt(prompt):
    modified_prompt = f"Scope of the Research for which survey needs to be conducted is:\n\n{prompt}\n\n provide me with questionnaire that can be asked to different set of people that will be involved in the study. questionnaire for each participants should be furthur divided into: Introduction question, Demographic Question, Main theme Question, Likert Scale/Rating Questions, Multiple-Choice Questions, Open-Ended Questions, Data Quality and Methodology."
    print(modified_prompt)
    response = openai.Completion.create(
        engine='text-davinci-003',
        prompt=modified_prompt,
        max_tokens=1000,
        temperature=0.7,
        n=1,
        stop=None,
        timeout=15,
    )
    
    if response['choices'][0]['text']:
        return response['choices'][0]['text'].strip()
    else:
        return None

# Get prompt from user
prompt = input("Enter your prompt: ")

# Generate response using the prompt
response = chat_with_gpt(prompt)
print(response)
# Out:
# Enter your prompt: The  Consultant/Firm  will  be  responsible  for  collecting  and analyzing  quality  data  according  totheexpectations  and  protocols,  and  within  a  timeframe.  The  tracer  study  aims  to  assess  the  effect  ofinterventions (covering long-term training ecosystem) on the labour market outcomes of the graduates.Thetracerstudytobecarried outunderthisconsultancy assignment willcoverthefollowing:a)To  measure  the  labor  market  performance  of  project  and  non-project  ITIs  disaggregated  bygenderandsocial groups.b)Sampling  with  statisticallysignificant  sample  and  designing  survey  instrument  in  consultationwith SDDc)Collect  information  of  students  who  are  not  in  employment/have  left  the  employment  and  thereasons for the same. While collecting such information specific reasons such as due to-Industryclosed becauseoflockdown, ReversemigrationduetoPandemicetc.shouldalsobeidentified.d)AssesstheimpactoftheITItrainingprogramsintermsofrelev
# ...

# %%
import openai

# Set up your API key
openai.api_key = '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'

# Define a function to interact with the ChatGPT API
def chat_with_gpt(prompt):
    modified_prompt = f"Scope of the Research for which survey needs to be conducted is:\n\n{prompt}\n\n provide me with questionnaire that can be asked to different set of people that will be involved in the study. questionnaire for each participants should be furthur divided into: Introduction question, Demographic Question, Main theme Question, Likert Scale/Rating Questions, Multiple-Choice Questions, Open-Ended Questions, Data Quality and Methodology with each section having 2,3 question."
    print(modified_prompt)
    response = openai.Completion.create(
        engine='text-babbage-001',
        prompt=modified_prompt,
        max_tokens=1000,
        temperature=0.7,
        n=1,
        stop=None,
        timeout=30,
    )
    
    if response['choices'][0]['text']:
        return response['choices'][0]['text'].strip()
    else:
        return None

# Get prompt from user
prompt = input("Enter your prompt: ")

# Generate response using the prompt
response = chat_with_gpt(prompt)
print(response)
# Out:
# Enter your prompt: The  Consultant/Firm  will  be  responsible  for  collecting  and analyzing  quality  data  according  totheexpectations  and  protocols,  and  within  a  timeframe.  The  tracer  study  aims  to  assess  the  effect  ofinterventions (covering long-term training ecosystem) on the labour market outcomes of the graduates.Thetracerstudytobecarried outunderthisconsultancy assignment willcoverthefollowing:a)To  measure  the  labor  market  performance  of  project  and  non-project  ITIs  disaggregated  bygenderandsocial groups.b)Sampling  with  statisticallysignificant  sample  and  designing  survey  instrument  in  consultationwith SDDc)Collect  information  of  students  who  are  not  in  employment/have  left  the  employment  and  thereasons for the same. While collecting such information specific reasons such as due to-Industryclosed becauseoflockdown, ReversemigrationduetoPandemicetc.shouldalsobeidentified.d)AssesstheimpactoftheITItrainingprogramsintermsofrelev
# ...

# %%
import openai

# Set up your API key
openai.api_key = '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'

# Define a function to interact with the ChatGPT API
def chat_with_gpt(prompt):
    modified_prompt = f"Scope of the Research for which survey needs to be conducted is:\n\n{prompt}\n\n provide me with questionnaire that can be asked to different set of people that will be involved in the study. questionnaire for each participants should be furthur divided into: Introduction question, Demographic Question, Main theme Question, Likert Scale/Rating Questions, Multiple-Choice Questions, Open-Ended Questions, Data Quality and Methodology."
    print(modified_prompt)
    response = openai.Completion.create(
        engine='text-curie-001',
        prompt=modified_prompt,
        max_tokens=1000,
        temperature=0.7,
        n=1,
        stop=None,
        timeout=30,
    )
    
    if response['choices'][0]['text']:
        return response['choices'][0]['text'].strip()
    else:
        return None

# Get prompt from user
prompt = input("Enter your prompt: ")

# Generate response using the prompt
response = chat_with_gpt(prompt)
print(response)
# Out:
# Enter your prompt: The  Consultant/Firm  will  be  responsible  for  collecting  and analyzing  quality  data  according  totheexpectations  and  protocols,  and  within  a  timeframe.  The  tracer  study  aims  to  assess  the  effect  ofinterventions (covering long-term training ecosystem) on the labour market outcomes of the graduates.Thetracerstudytobecarried outunderthisconsultancy assignment willcoverthefollowing:a)To  measure  the  labor  market  performance  of  project  and  non-project  ITIs  disaggregated  bygenderandsocial groups.b)Sampling  with  statisticallysignificant  sample  and  designing  survey  instrument  in  consultationwith SDDc)Collect  information  of  students  who  are  not  in  employment/have  left  the  employment  and  thereasons for the same. While collecting such information specific reasons such as due to-Industryclosed becauseoflockdown, ReversemigrationduetoPandemicetc.shouldalsobeidentified.d)AssesstheimpactoftheITItrainingprogramsintermsofrelev
# ...

# %%
import openai

# Set up your API key
openai.api_key = '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'

# Define a function to interact with the ChatGPT API
def chat_with_gpt(prompt):
    modified_prompt = f"Scope of the Research for which survey needs to be conducted is:\n\n{prompt}\n\n provide me with questionnaire that can be asked to different set of people that will be involved in the study. questionnaire for each participants should be furthur divided into: Introduction question, Demographic Question, Main theme Question, Likert Scale/Rating Questions, Multiple-Choice Questions, Open-Ended Questions, Data Quality and Methodology."
    print(modified_prompt)
    response = openai.Completion.create(
        engine='text-ada-001',
        prompt=modified_prompt,
        max_tokens=1000,
        temperature=0.7,
        n=1,
        stop=None,
        timeout=30,
    )
    
    if response['choices'][0]['text']:
        return response['choices'][0]['text'].strip()
    else:
        return None

# Get prompt from user
prompt = input("Enter your prompt: ")

# Generate response using the prompt
response = chat_with_gpt(prompt)
print(response)
# Out:
# Enter your prompt: The  Consultant/Firm  will  be  responsible  for  collecting  and analyzing  quality  data  according  totheexpectations  and  protocols,  and  within  a  timeframe.  The  tracer  study  aims  to  assess  the  effect  ofinterventions (covering long-term training ecosystem) on the labour market outcomes of the graduates.Thetracerstudytobecarried outunderthisconsultancy assignment willcoverthefollowing:a)To  measure  the  labor  market  performance  of  project  and  non-project  ITIs  disaggregated  bygenderandsocial groups.b)Sampling  with  statisticallysignificant  sample  and  designing  survey  instrument  in  consultationwith SDDc)Collect  information  of  students  who  are  not  in  employment/have  left  the  employment  and  thereasons for the same. While collecting such information specific reasons such as due to-Industryclosed becauseoflockdown, ReversemigrationduetoPandemicetc.shouldalsobeidentified.d)AssesstheimpactoftheITItrainingprogramsintermsofrelev
# ...

# %%
import openai

# Set up your API key
openai.api_key = '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'

# Define a function to interact with the ChatGPT API
def chat_with_gpt(prompt):
    modified_prompt = f"Scope of the Research for which survey needs to be conducted is:\n\n{prompt}\n\n provide me with questionnaire that can be asked to different set of people that will be involved in the study. questionnaire for each participants should be furthur divided into: Introduction question, Demographic Question, Main theme Question, Likert Scale/Rating Questions, Multiple-Choice Questions, Open-Ended Questions, Data Quality and Methodology."
    print(modified_prompt)
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": modified_prompt}
        ]
    )
    
    if response['choices'][0]['message']['content']:
        return response['choices'][0]['message']['content'].strip()
    else:
        return None

# Get prompt from user
prompt = input("Enter your prompt: ")

# Generate response using the prompt
response = chat_with_gpt(prompt)
print(response)
# Out:
# Enter your prompt: The  Consultant/Firm  will  be  responsible  for  collecting  and analyzing  quality  data  according  totheexpectations  and  protocols,  and  within  a  timeframe.  The  tracer  study  aims  to  assess  the  effect  ofinterventions (covering long-term training ecosystem) on the labour market outcomes of the graduates.Thetracerstudytobecarried outunderthisconsultancy assignment willcoverthefollowing:a)To  measure  the  labor  market  performance  of  project  and  non-project  ITIs  disaggregated  bygenderandsocial groups.b)Sampling  with  statisticallysignificant  sample  and  designing  survey  instrument  in  consultationwith SDDc)Collect  information  of  students  who  are  not  in  employment/have  left  the  employment  and  thereasons for the same. While collecting such information specific reasons such as due to-Industryclosed becauseoflockdown, ReversemigrationduetoPandemicetc.shouldalsobeidentified.d)AssesstheimpactoftheITItrainingprogramsintermsofrelev
# ...

# %%
import openai

# Set up your API key
openai.api_key = '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'

# Define a function to interact with the ChatGPT API
def chat_with_gpt(prompt):
    modified_prompt = f"Scope of the Research for which survey needs to be conducted is:\n\n{prompt}\n\n provide me with questionnaire that can be asked to different set of people that will be involved in the study."
    print(modified_prompt)
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": modified_prompt}
        ]
    )
    
    if response['choices'][0]['message']['content']:
        return response['choices'][0]['message']['content'].strip()
    else:
        return None

# Get prompt from user
prompt = input("Enter your prompt: ")

# Generate response using the prompt
response = chat_with_gpt(prompt)
print(response)
# Out:
# Enter your prompt: The  Consultant/Firm  will  be  responsible  for  collecting  and analyzing  quality  data  according  totheexpectations  and  protocols,  and  within  a  timeframe.  The  tracer  study  aims  to  assess  the  effect  ofinterventions (covering long-term training ecosystem) on the labour market outcomes of the graduates.Thetracerstudytobecarried outunderthisconsultancy assignment willcoverthefollowing:a)To  measure  the  labor  market  performance  of  project  and  non-project  ITIs  disaggregated  bygenderandsocial groups.b)Sampling  with  statisticallysignificant  sample  and  designing  survey  instrument  in  consultationwith SDDc)Collect  information  of  students  who  are  not  in  employment/have  left  the  employment  and  thereasons for the same. While collecting such information specific reasons such as due to-Industryclosed becauseoflockdown, ReversemigrationduetoPandemicetc.shouldalsobeidentified.d)AssesstheimpactoftheITItrainingprogramsintermsofrelev
# ...

# %%
import openai

# Set up your API key
openai.api_key = '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'

# Define a function to interact with the ChatGPT API
def chat_with_gpt(prompt):
    modified_prompt = f"Scope of the Research for which survey needs to be conducted is:\n\n{prompt}\n\n provide me with questionnaire that can be asked to different set of people that will be involved in the study."
    print(modified_prompt)
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo-16k",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": modified_prompt}
        ]
    )
    
    if response['choices'][0]['message']['content']:
        return response['choices'][0]['message']['content'].strip()
    else:
        return None

# Get prompt from user
prompt = input("Enter your prompt: ")

# Generate response using the prompt
response = chat_with_gpt(prompt)
print(response)
# Out:
# Enter your prompt: The  Consultant/Firm  will  be  responsible  for  collecting  and analyzing  quality  data  according  totheexpectations  and  protocols,  and  within  a  timeframe.  The  tracer  study  aims  to  assess  the  effect  ofinterventions (covering long-term training ecosystem) on the labour market outcomes of the graduates.Thetracerstudytobecarried outunderthisconsultancy assignment willcoverthefollowing:a)To  measure  the  labor  market  performance  of  project  and  non-project  ITIs  disaggregated  bygenderandsocial groups.b)Sampling  with  statisticallysignificant  sample  and  designing  survey  instrument  in  consultationwith SDDc)Collect  information  of  students  who  are  not  in  employment/have  left  the  employment  and  thereasons for the same. While collecting such information specific reasons such as due to-Industryclosed becauseoflockdown, ReversemigrationduetoPandemicetc.shouldalsobeidentified.d)AssesstheimpactoftheITItrainingprogramsintermsofrelev
# ...

# %%
'''import openai
from transformers import pipeline

# Set up your API key
openai.api_key = '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'

# Define a function to summarize the data
def summarize_data(data):
    summarizer = pipeline("summarization")
    summarized_text = summarizer(data, min_length=30, do_sample=False)
    return summarized_text[0]['summary_text']

# Define a function to interact with the ChatGPT API
def chat_with_gpt(prompt):
    # Summarize the user's input
    summarized_prompt = summarize_data(prompt)

    # Customize the prompt by adding lines before and after the summarized text
    modified_prompt = f"Scope of the Research for which survey needs to be conducted is:\n\n{summarized_prompt}\n\n provide me with questionnaire that can be asked to different set of people that will be involved in the study."

    response = openai.Completion.create(
        engine='text-davinci-003',
        prompt=modified_prompt,
        max_tokens=100,
        temperature=0.7,
        n=1,
        stop=None,
        timeout=15,
    )

    if response['choices'][0]['text']:
        return response['choices'][0]['text'].strip()
    else:
        return None

# Get prompt from user
user_prompt = input("Enter your data: ")

# Generate response using the modified and summarized prompt
response = chat_with_gpt(user_prompt)
print(response)
'''
# Out:
# 'import openai\nfrom transformers import pipeline\n\n# Set up your API key\nopenai.api_key = \'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\'\n\n# Define a function to summarize the data\ndef summarize_data(data):\n    summarizer = pipeline("summarization")\n    summarized_text = summarizer(data, min_length=30, do_sample=False)\n    return summarized_text[0][\'summary_text\']\n\n# Define a function to interact with the ChatGPT API\ndef chat_with_gpt(prompt):\n    # Summarize the user\'s input\n    summarized_prompt = summarize_data(prompt)\n\n    # Customize the prompt by adding lines before and after the summarized text\n    modified_prompt = f"Scope of the Research for which survey needs to be conducted is:\n\n{summarized_prompt}\n\n provide me with questionnaire that can be asked to different set of people that will be involved in the study."\n\n    response = openai.Completion.create(\n        engine=\'text-davinci-003\',\n        prompt=modified_prompt,\n        max_token
# ...

# %%
import openai
from transformers import pipeline

# Set up your API key
openai.api_key = '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'

# Define a function to interact with the ChatGPT API
def chat_with_gpt(prompt1, prompt2):

    modified_prompt = f"Scope of the Research for which survey needs to be conducted is:\n\n{prompt1}\n\n provide me with questionnaire that can be asked to the :\n\n{prompt2}\n\n. questionnaire should be divided in sections as Demographic Information, Main theme Question (you need to identify theme of the scope from the content provided, question understanding there thoughts and likeablity. all section should have open ended and mcq questions, "
    print(modified_prompt)
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": modified_prompt}
        ]
    )
    
    if response['choices'][0]['message']['content']: 
        return response['choices'][0]['message']['content'].strip()
    else:
        return None

# Get prompt from user
user_prompt1 = input("Enter your prompt: ")
user_prompt2 = input("Please specify the intended respondent for whom you would like to generate the questionnaire: ")

# Generate response using the prompt
response = chat_with_gpt(user_prompt1, user_prompt2)
print(response)
# Out:
# Enter your prompt: The  Consultant/Firm  will  be  responsible  for  collecting  and analyzing  quality  data  according  totheexpectations  and  protocols,  and  within  a  timeframe.  The  tracer  study  aims  to  assess  the  effect  ofinterventions (covering long-term training ecosystem) on the labour market outcomes of the graduates.Thetracerstudytobecarried outunderthisconsultancy assignment willcoverthefollowing:a)To  measure  the  labor  market  performance  of  project  and  non-project  ITIs  disaggregated  bygenderandsocial groups.b)Sampling  with  statisticallysignificant  sample  and  designing  survey  instrument  in  consultationwith SDDc)Collect  information  of  students  who  are  not  in  employment/have  left  the  employment  and  thereasons for the same. While collecting such information specific reasons such as due to-Industryclosed becauseoflockdown, ReversemigrationduetoPandemicetc.shouldalsobeidentified.d)AssesstheimpactoftheITItrainingprogramsintermsofrelev
# ...

# %%
import openai

# Set up your API key
openai.api_key = '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'

# Define a function to interact with the ChatGPT API
def chat_with_gpt(prompt):
    modified_prompt = f"Scope of the Research for which survey needs to be conducted is:\n\n{prompt}\n\n provide me with questionnaire that can be asked to different set of people that will be involved in the study. questionnaire for each participants should be furthur divided into: Introduction question, Demographic Question, Main theme Question, Likert Scale/Rating Questions, Multiple-Choice Questions, Open-Ended Questions, Data Quality and Methodology."
    print(modified_prompt)
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo-16k",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": modified_prompt}
        ]
    )
    
    if response['choices'][0]['message']['content']:
        return response['choices'][0]['message']['content'].strip()
    else:
        return None

# Get prompt from user
prompt = input("Enter your prompt: ")

# Generate response using the prompt
response = chat_with_gpt(prompt)
print(response)
# Out:
# Enter your prompt: The  Consultant/Firm  will  be  responsible  for  collecting  and analyzing  quality  data  according  totheexpectations  and  protocols,  and  within  a  timeframe.  The  tracer  study  aims  to  assess  the  effect  ofinterventions (covering long-term training ecosystem) on the labour market outcomes of the graduates.Thetracerstudytobecarried outunderthisconsultancy assignment willcoverthefollowing:a)To  measure  the  labor  market  performance  of  project  and  non-project  ITIs  disaggregated  bygenderandsocial groups.b)Sampling  with  statisticallysignificant  sample  and  designing  survey  instrument  in  consultationwith SDDc)Collect  information  of  students  who  are  not  in  employment/have  left  the  employment  and  thereasons for the same. While collecting such information specific reasons such as due to-Industryclosed becauseoflockdown, ReversemigrationduetoPandemicetc.shouldalsobeidentified.d)AssesstheimpactoftheITItrainingprogramsintermsofrelev
# ...

# %%
import openai

# Set up your API key
openai.api_key = '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'

# Define a function to interact with the ChatGPT API
def chat_with_gpt(prompt):
    modified_prompt = f"Scope of the Research for which survey needs to be conducted is:\n\n{prompt}\n\n provide me with questionnaire that can be asked to different set of people that will be involved in the study. questionnaire for each participants should be furthur divided into: Introduction question, Demographic Question, Main theme Question(write what is the main theme you come up with instead of writing main theme as a header)"
    print(modified_prompt)
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo-16k",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": modified_prompt}
        ]
    )
    
    if response['choices'][0]['message']['content']:
        return response['choices'][0]['message']['content'].strip()
    else:
        return None

# Get prompt from user
prompt = input("Enter your prompt: ")

# Generate response using the prompt
response = chat_with_gpt(prompt)
print(response)
# Out:
# Enter your prompt: The  Consultant/Firm  will  be  responsible  for  collecting  and analyzing  quality  data  according  totheexpectations  and  protocols,  and  within  a  timeframe.  The  tracer  study  aims  to  assess  the  effect  ofinterventions (covering long-term training ecosystem) on the labour market outcomes of the graduates.Thetracerstudytobecarried outunderthisconsultancy assignment willcoverthefollowing:a)To  measure  the  labor  market  performance  of  project  and  non-project  ITIs  disaggregated  bygenderandsocial groups.b)Sampling  with  statisticallysignificant  sample  and  designing  survey  instrument  in  consultationwith SDDc)Collect  information  of  students  who  are  not  in  employment/have  left  the  employment  and  thereasons for the same. While collecting such information specific reasons such as due to-Industryclosed becauseoflockdown, ReversemigrationduetoPandemicetc.shouldalsobeidentified.d)AssesstheimpactoftheITItrainingprogramsintermsofrelev
# ...

# %%
import openai

# Set up your API key
openai.api_key = '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'

# Define a function to interact with the ChatGPT API
def chat_with_gpt(prompt1, prompt2):
    modified_prompt = f"Scope of the Research for which survey needs to be conducted is:\n\n{prompt1}\n\n provide me with questionnaire that can be asked to the :\n\n{prompt2}\n\nprovide me with questionnaire that can be asked to different set of people that will be involved in the study. questionnaire for each participants should be furthur divided into: Introduction question, Demographic Question, Main theme Question(write what is the main theme you come up with instead of writing main theme as a header)"
    print(modified_prompt)
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo-16k",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": modified_prompt}
        ]
    )
    
    if response['choices'][0]['message']['content']:
        return response['choices'][0]['message']['content'].strip()
    else:
        return None

# Get prompt from user
user_prompt1 = input("Enter your prompt: ")
user_prompt2 = input("Please specify the intended respondent for whom you would like to generate the questionnaire: ")

# Generate response using the prompt
response = chat_with_gpt(user_prompt1, user_prompt2)
print(response)
# Out:
# Enter your prompt: Research Scope: Assessing Interest in Hiring Third-Party Services for Customer Satisfaction Surveys  Introduction:  Provide an overview of the research project and its objectives. Explain the importance of understanding the interest of companies or potential clients in hiring third-party services for conducting customer satisfaction surveys. Research Objectives:  Determine the level of interest among companies in hiring third-party services for customer satisfaction surveys. Identify the factors that influence companies' decision to outsource survey services. Understand the potential clients' needs and expectations regarding customer satisfaction surveys. Evaluate the size and nature of companies interested in utilizing third-party services for survey research. Identify the preferred methods and channels for conducting customer satisfaction surveys. Gather insights on the frequency and timing of survey implementation. Target Audience:  Define the target audience as
# ...

# %%
import openai

# Set up your API key
openai.api_key = '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'

# Define a function to interact with the ChatGPT API
def chat_with_gpt(prompt1, prompt2):
    modified_prompt = f"Scope of the Research for which survey needs to be conducted is:\n\n{prompt1}\n\n provide me with questionnaire that can be asked to the :\n\n{prompt2}\n\nprovide me with questionnaire that can be asked to different set of people that will be involved in the study. questionnaire for each participants should be furthur divided into: Introduction question, Demographic Question, Main theme Question(try to understand main theme of the reseach and use that as a header)"
    print(modified_prompt)
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo-16k",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": modified_prompt}
        ]
    )
    
    if response['choices'][0]['message']['content']:
        return response['choices'][0]['message']['content'].strip()
    else:
        return None

# Get prompt from user
user_prompt1 = input("Enter your prompt: ")
user_prompt2 = input("Please specify the intended respondent for whom you would like to generate the questionnaire: ")

# Generate response using the prompt
response = chat_with_gpt(user_prompt1, user_prompt2)
print(response)
# Out:
# Enter your prompt: Research Scope: Assessing Interest in Hiring Third-Party Services for Customer Satisfaction Surveys  Introduction:  Provide an overview of the research project and its objectives. Explain the importance of understanding the interest of companies or potential clients in hiring third-party services for conducting customer satisfaction surveys. Research Objectives:  Determine the level of interest among companies in hiring third-party services for customer satisfaction surveys. Identify the factors that influence companies' decision to outsource survey services. Understand the potential clients' needs and expectations regarding customer satisfaction surveys. Evaluate the size and nature of companies interested in utilizing third-party services for survey research. Identify the preferred methods and channels for conducting customer satisfaction surveys. Gather insights on the frequency and timing of survey implementation. Target Audience:  Define the target audience as
# ...

# %%
import openai

# Set up your API key
openai.api_key = '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'

# Define a function to interact with the ChatGPT API
def chat_with_gpt(prompt1, prompt2, prompt3):
    modified_prompt = f"Scope of the Research for which survey needs to be conducted is:\n\n{prompt1}\n\n provide me with questionnaire that can be asked to the :\n\n{prompt2}\n\n Type of survey is:\n\n{prompt3}\n\n provide me with questionnaire that can be asked to different set of people that will be involved in the study. questionnaire for each participants should be furthur divided into: Introduction question, Demographic Question, Main theme Question and sub main themes and each section should have multiple choice, likerat scale and open ended questions. for example: tracer study for a eductaion training could involve educational training, Employment status/high study status, impact of the training, etc"    
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo-16k",
        max_tokens = 1000,
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": modified_prompt}
        ]
    )
    
    if response['choices'][0]['message']['content']:
        return response['choices'][0]['message']['content'].strip()
    else:
        return None

# Get prompt from user
user_prompt1 = input("Enter your Scope: ")
user_prompt2 = input("Please specify the intended respondent for whom you would like to generate the questionnaire: ")
user_prompt3 = input("Type of Survey")


# Generate response using the prompt
response = chat_with_gpt(user_prompt1, user_prompt2, user_prompt3)
print(response)
# Out:
# Enter your Scope: Assessing Interest in Hiring Third-Party Services for Customer Satisfaction Surveys  Introduction:  Provide an overview of the research project and its objectives. Explain the importance of understanding the interest of companies or potential clients in hiring third-party services for conducting customer satisfaction surveys. Research Objectives:  Determine the level of interest among companies in hiring third-party services for customer satisfaction surveys. Identify the factors that influence companies' decision to outsource survey services. Understand the potential clients' needs and expectations regarding customer satisfaction surveys. Evaluate the size and nature of companies interested in utilizing third-party services for survey research. Identify the preferred methods and channels for conducting customer satisfaction surveys. Gather insights on the frequency and timing of survey implementation. Target Audience:  Define the target audience as companies or org
# ...
